# %%
import pandas as pd

# Relative to your .ipynb file location
zip_path = "data/budapest_gtfs.zip"
internal_file = "stops.txt"

# Ensure the path is absolute or clearly defined for fsspec
df_stops = pd.read_csv(
    f"zip://{internal_file}::file://{zip_path}",
    sep=",",
    # usecols=["stop_id", "stop_name", "wheelchair_boarding"]
)

print(f"Loaded {len(df_stops)} stops.")
print(df_stops.info())
# Out:
# Loaded 6196 stops.
# <class 'pandas.DataFrame'>
# RangeIndex: 6196 entries, 0 to 6195
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   stop_id              6196 non-null   str
#  1   stop_name            6196 non-null   str
#  2   stop_lat             6196 non-null   float64
#  3   stop_lon             6196 non-null   float64
#  4   stop_code            6196 non-null   str
#  5   location_type        466 non-null    float64
#  6   location_sub_type    212 non-null    str
#  7   parent_station       531 non-null    str
#  8   wheelchair_boarding  5888 non-null   float64
# dtypes: float64(4), str(5)
# memory usage: 435.8 KB
# None
